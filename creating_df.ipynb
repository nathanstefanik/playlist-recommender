# %%
import numpy as np
import pandas as pd

# %%
one = pd.read_csv('tracks_features.csv')
print(one.shape)
print(one.columns)
one.head()
# Out:
# (1204025, 24)
# Index(['id', 'name', 'album', 'album_id', 'artists', 'artist_ids',
#        'track_number', 'disc_number', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'time_signature', 'year', 'release_date'],
#       dtype='object')
#                        id                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# ...

# %%
one[one['album'].str.lower() == 'punisher']
# Out:
#                              id               name     album  \
# 1138422  6Tz8qANEIf4aCGEEjcxgKg           DVD Menu  Punisher
# 1138423  5uQRmdIqyMmKPWJcot4UmV        Garden Song  Punisher
# 1138424  49UDOG8DoBajXTJSTqfRMg              Kyoto  Punisher
# 1138425  7yR6GEJsPI6kmNRvFkPuN3           Punisher  Punisher
# 1138426  7FQ2JgfdkBcBb3BEbu8Axf          Halloween  Punisher
# 1138427  60zlkOrTCHjpRTd1g6PI5y  Chinese Satellite  Punisher
# 1138428  6sALLrBPX30ptG1HWH6vmW          Moon Song  Punisher
# 1138429  4BNew3AqFCvABdFsYMRiyB     Savior Complex  Punisher
# 1138430  38KCyQcBswyAd7xSQnDIU4                ICU  Punisher
# 1138431  44spdItKKM7rOtKswbBG0U      Graceland Too  Punisher
# 1138432  3cr3oAP4bQFNjZBV7ElKaB     I Know The End  Punisher
#
#                        album_id              artists  \
# 1138422  2xECuqnvvmVktV7UO8Dd3s  ['Phoebe Bridgers']
# 1138423  2xECuqnvvmVktV7UO8Dd3s  ['Phoebe Bridgers']
# 1138424  2xECuqnvvmVktV7UO8Dd3s  ['Phoebe Bridgers']
# ...

# %%
fuck = one[['id', 'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']]
fuck.head()
# Out:
#                        id  explicit  danceability  energy  key  loudness  \
# 0  7lmeHLHBe4nmXzuXc0HDjk     False         0.470   0.978    7    -5.399
# 1  1wsRitfRRtWyEapl0q22o8      True         0.599   0.957   11    -5.764
# 2  1hR0fIFK2qRG3f3RF70pb7     False         0.315   0.970    7    -5.424
# 3  2lbASgTSoDO7MTuLAXlTW0      True         0.440   0.967   11    -5.830
# 4  1MQTmpYOZ6fcMQc56Hdo7T     False         0.426   0.929    2    -6.729
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0727       0.02610          0.000011    0.3560    0.503
# 1     1       0.1880       0.01290          0.000071    0.1550    0.489
# 2     1       0.4830       0.02340          0.000002    0.1220    0.370
# 3     0       0.2370       0.16300          0.000004    0.1210    0.574
# 4     1       0.0701       0.00162          0.105000    0.0789    0.539
#
#      tempo  time_signature
# 0  117.906             4.0
# 1  103.680             4.0
# ...

# %%
fuck.loc['explicit'] = 0 if 'False' else 1
# Out:
# /var/folders/jc/l8gc1q891rl5rcv8zg4yjywm0000gn/T/ipykernel_1740/1525454427.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fuck.loc['explicit'] = 0 if 'False' else 1

# %%
fuck.head()
fuck.to_pickle('tracks_features_processed.pkl')

# %%
# playlist = pd.read_json('spotify_million_playlist_dataset/data/mpd.slice.0-999.json')
import json
# load data using Python JSON module
with open('spotify_million_playlist_dataset/data/mpd.slice.0-999.json','r') as f:
    data = json.loads(f.read())
    
# Normalizing data
df = pd.json_normalize(data, record_path =['playlists'])

# %%
df.head()
# Out:
#                name collaborative  pid  modified_at  num_tracks  num_albums  \
# 0        Throwbacks         false    0   1493424000          52          47
# 1  Awesome Playlist         false    1   1506556800          39          23
# 2           korean          false    2   1505692800          64          51
# 3               mat         false    3   1501027200         126         107
# 4               90s         false    4   1401667200          17          16
#
#    num_followers                                             tracks  \
# 0              1  [{'pos': 0, 'artist_name': 'Missy Elliott', 't...
# 1              1  [{'pos': 0, 'artist_name': 'Survivor', 'track_...
# 2              1  [{'pos': 0, 'artist_name': 'Hoody', 'track_uri...
# 3              1  [{'pos': 0, 'artist_name': 'Camille Saint-Saën...
# 4              2  [{'pos': 0, 'artist_name': 'The Smashing Pumpk...
#
#    num_edits  duration_ms  num_artists description
# ...

# %%
df['tracks'][0]
# Out:
# [{'pos': 0,
#   'artist_name': 'Missy Elliott',
#   'track_uri': 'spotify:track:0UaMYEvWZi0ZqiDOoHU3YI',
#   'artist_uri': 'spotify:artist:2wIVse2owClT7go1WT98tk',
#   'track_name': 'Lose Control (feat. Ciara & Fat Man Scoop)',
#   'album_uri': 'spotify:album:6vV5UrXcfyQD1wu4Qo2I9K',
#   'duration_ms': 226863,
#   'album_name': 'The Cookbook'},
#  {'pos': 1,
#   'artist_name': 'Britney Spears',
#   'track_uri': 'spotify:track:6I9VzXrHxO9rA9A5euc8Ak',
#   'artist_uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4',
#   'track_name': 'Toxic',
#   'album_uri': 'spotify:album:0z7pVBGOD7HCIB7S8eLkLI',
#   'duration_ms': 198800,
#   'album_name': 'In The Zone'},
#  {'pos': 2,
#   'artist_name': 'Beyoncé',
#   'track_uri': 'spotify:track:0WqIKmW4BTrj3eJFmnCKMv',
#   'artist_uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m',
#   'track_name': 'Crazy In Love',
#   'album_uri': 'spotify:album:25hVFAxTlDvXbx2X2QkUkE',
#   'duration_ms': 235933,
# ...

# %%
song_id = one[['id', 'name', 'album', 'album_id', 'artists', 'artist_ids', 'duration_ms']]

# %%
song_id[song_id['id'] == '0WqIKmW4BTrj3eJFmnCKMv']
# Out:
# Empty DataFrame
# Columns: [id, name, album, album_id, artists, artist_ids, duration_ms]
# Index: []

# %%
fucker = song_id[song_id['name'] =='Toxic'].copy()

# %%
import ast

def convert_to_tracks(tracks_dict):
    tracks = []
    for track in tracks_dict:
        print(track['track_name'])
        album = track['album_name']
        duration = track['duration_ms']
        track_name = track['track_name']
        tmp_df = song_id[song_id['name'] == track_name].copy()
        tmp_df = song_id[song_id['album'] == album].copy()
        tmp_df = tmp_df[tmp_df['duration_ms'] < duration + 100].copy()
        tmp_df = tmp_df[tmp_df['duration_ms'] > duration - 100].copy()
        print(list(tmp_df['id']))
    return pd.Series(data=tracks)

# %%
fuck = convert_to_tracks(df['tracks'][0])
# Out:
# Lose Control (feat. Ciara & Fat Man Scoop)
# []
# Toxic
# ['6I9VzXrHxO9rA9A5euc8Ak']
# Crazy In Love
# []
# Rock Your Body
# ['1AWQoqb9bSvzTjaLralEkT']
# It Wasn't Me
# []
# Yeah!
# []
# My Boo
# []
# Buttons
# []
# Say My Name
# ['7H6ev70Weq6DdpZyyTmUXk']
# Hey Ya! - Radio Mix / Club Mix
# ['2PpruBYCo4H7WOBJ7Q2EwM']
# Promiscuous
# []
# Right Where You Want Me - Radio Edit Version
# []
# Beautiful Soul
# []
# Leavin'
# []
# Me & U
# []
# Ice Box
# []
# Sk8er Boi
# ['00Mb3DuaIH1kjrwOku9CGU']
# Run It!
# []
# Check On It - feat. Bun B and Slim Thug
# ['2RWxrpsFshOBFwRBRstUlQ']
# Jumpin', Jumpin'
# ['4pmc2AxSEq6g7hPVlJCPyP']
# Soak Up The Sun
# []
# Where Is The Love?
# []
# Stacy's Mom
# ['19Js5ypV6JKn4DMExHQbGc']
# Just The Girl
# []
# Yo (Excuse Me Miss)
# []
# Year 3000
# []
# Lip Gloss
# []
# Everytime We Touch - Radio Edit
# []
# Whatcha Say
# []
# Miss Independent
# []
# Party In The U.S.A.
# []
# The Great Escape
# []
# Replay
# ['5vlEg2fT4cFWAqU5QptIpQ']
# Forever
# []
# ...

# %%
print(fuck)
# Out:
# Series([], dtype: float64)

# %%
two = one[one['name'].str.contains('Lose Control')]
print(type(two['artists'].iloc[0]))
# Out:
# <class 'str'>

# %%
three = two['artists'].to_list()

# %%
import ast
 
# initializing string representation of a list
ini_list = three[0]
 
 
# Converting string to list
res = ast.literal_eval(ini_list)
 
# printing final result and its type
print(res)
print(type(res))
# Out:
# ['Elu']
# <class 'list'>

# %%
print(lst)
# Out:
# ["['one',", "'two']"]

# %%
import json
 
 
res = json.loads(list_str)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [40], in <cell line: 4>()
#       1 import json
# ----> 4 res = json.loads(list_str)
#
# File ~/mambaforge/envs/ml/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/mambaforge/envs/ml/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
# ...

# %%
import ast
 
# initializing string representation of a list
ini_list = list_str
 
 
# Converting string to list
res = ast.literal_eval(ini_list)
 
# printing final result and its type
print(res)
print(type(res))
# Out:
# ['one', 'two']
# <class 'list'>

# %%
track_identifier = one[['id', 'name', 'album', 'artists', 'duration_ms']].copy()

# %%
import ast
track_identifier['artists'] = track_identifier['artists'].apply(lambda row : ast.literal_eval(row))

# %%
track_identifier.to_pickle('track_identifier.pkl')
